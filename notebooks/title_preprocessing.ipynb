# %%
from pathlib import Path
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.utils import simple_preprocess
import numpy as np
import pandas as pd
from songs_analyzer.config import get_root_path

from sklearn.neighbors import NearestNeighbors

# %%
songs_data_path = get_root_path() / "data/raw/song_feature_data.csv"

songs_df = pd.read_csv(songs_data_path)

# %%
songs_df.head()
# Out:
#                                     uri                                  name  \
# 0  spotify:track:7fgC7BPn2SzVno2d7ooLGI  Rufus Wainwright Spotify Pride Intro
# 1  spotify:track:3l6EkMrhwXPSVEuTDksWB8         Cigarettes And Chocolate Milk
# 2  spotify:track:2PwYIEV1H34mbQBvbnnmLx                      Over the Rainbow
# 3  spotify:track:6bFrlORduDtYQ9BlPenV3o             My Baby Just Cares For Me
# 4  spotify:track:3uxg8Hl1NFVySLDL0euMbu                             Cre Spoda
#
#              artist  popularity  danceability  energy  key  loudness  mode  \
# 0   Various Artists           0         0.000  0.6290   10    -8.432     0
# 1  Rufus Wainwright          44         0.328  0.3570    4    -9.939     1
# 2      Judy Garland           0         0.231  0.0426    8   -21.141     1
# 3       Nina Simone           0         0.760  0.1960   11   -17.872     0
# 4        Klaus Nomi          16         0.234  0.8580    8    -6.145     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0000         0.348          0.000000    0.3830    0.000    0.000
# 1       0.0274         0.791          0.000000    0.0832    0.161   97.816
# 2       0.0426         0.901          0.000136    0.1530    0.199   77.740
# 3       0.1110         0.812          0.000002    0.0845    0.418  118.348
# 4       0.0710         0.337          0.459000    0.2280    0.200  127.745
#
#    duration_ms  time_signature
# 0        13750               0
# 1       280360               4
# 2       166467               4
# 3       216689               4
# 4       183947               4

# %%
music_name_feature = [simple_preprocess(str(music_name).lower()) for music_name in songs_df["name"]]
music_name_tagged = [TaggedDocument(tokens, [i]) for i, tokens in enumerate(music_name_feature)]
music_name_tagged
# Out:
# [TaggedDocument(words=['rufus', 'wainwright', 'spotify', 'pride', 'intro'], tags=[0]),
#  TaggedDocument(words=['cigarettes', 'and', 'chocolate', 'milk'], tags=[1]),
#  TaggedDocument(words=['over', 'the', 'rainbow'], tags=[2]),
#  TaggedDocument(words=['my', 'baby', 'just', 'cares', 'for', 'me'], tags=[3]),
#  TaggedDocument(words=['cre', 'spoda'], tags=[4]),
#  TaggedDocument(words=['dance', 'disco', 'heat'], tags=[5]),
#  TaggedDocument(words=['do', 'you', 'really', 'want', 'to', 'hurt', 'me'], tags=[6]),
#  TaggedDocument(words=['freedom'], tags=[7]),
#  TaggedDocument(words=['goodbye', 'yellow', 'brick', 'road'], tags=[8]),
#  TaggedDocument(words=['sometimes', 'you', 'need'], tags=[9]),
#  TaggedDocument(words=['it', 'sin'], tags=[10]),
#  TaggedDocument(words=['rufus', 'wainwright', 'on', 'pride'], tags=[11]),
#  TaggedDocument(words=['swings', 'both', 'ways'], tags=[12]),
#  TaggedDocument(words=['come', 'rain', 'or', 'come', 'shine', 'live'], tags=[13]),
#  TaggedDocument(words=['wish', 'knew', 'how', 'it', 'would', 'feel', 'to', 'be', 'free'], tags=[14]),
#  TaggedDocument(words=['true', 'colors'], tags=[15]),
#  TaggedDocument(words=['goldfinger'], tags=[16]),
#  TaggedDocument(words=['cabaret', 'married'], tags=[17]),
#  TaggedDocument(words=['in', 'between', 'the', 'heartaches', 'ichiban'], tags=[18]),
#  TaggedDocument(words=['off', 'the', 'wall'], tags=[19]),
#  TaggedDocument(words=['aigle', 'noir'], tags=[20]),
#  TaggedDocument(words=['everything', 'coming', 'up', 'roses'], tags=[21]),
#  TaggedDocument(words=['mississippi', 'goddam'], tags=[22]),
#  TaggedDocument(words=['gay', 'messiah'], tags=[23]),
#  TaggedDocument(words=['bloody', 'mother', 'fucking', 'asshole'], tags=[24]),
#  TaggedDocument(words=['the', 'rose'], tags=[25]),
#  TaggedDocument(words=['queen'], tags=[26]),
#  TaggedDocument(words=['fourth', 'of', 'july'], tags=[27]),
#  TaggedDocument(words=['going', 'to', 'town'], tags=[28]),
#  TaggedDocument(words=['when', 'in', 'disgrace', 'with', 'fortune', 'and', 'men', 'eyes', 'sonnet'], tags=[29]),
#  TaggedDocument(words=['welcome', 'italian', 'greetings'], tags=[30]),
#  TaggedDocument(words=['please', 'thank', 'you', 'you', 're', 'welcome'], tags=[31]),
#  TaggedDocument(words=['asking', 'how', 'are', 'you'], tags=[32]),
#  TaggedDocument(words=['numbers'], tags=[33]),
#  TaggedDocument(words=['asking', 'what', 'is', 'your', 'name'], tags=[34]),
#  TaggedDocument(words=['numbers'], tags=[35]),
#  TaggedDocument(words=['to', 'be', 'telling', 'time', 'asking', 'questions'], tags=[36]),
#  TaggedDocument(words=['numbers'], tags=[37]),
#  TaggedDocument(words=['to', 'have', 'asking', 'someone', 'age'], tags=[38]),
#  TaggedDocument(words=['to', 'make', 'to', 'do'], tags=[39]),
#  TaggedDocument(words=['to', 'go'], tags=[40]),
#  TaggedDocument(words=['to', 'call'], tags=[41]),
#  TaggedDocument(words=['to', 'speak'], tags=[42]),
#  TaggedDocument(words=['numbers'], tags=[43]),
#  TaggedDocument(words=['to', 'take', 'to', 'get'], tags=[44]),
#  TaggedDocument(words=['to', 'want'], tags=[45]),
#  TaggedDocument(words=['days', 'of', 'the', 'week'], tags=[46]),
#  TaggedDocument(words=['to', 'sleep'], tags=[47]),
#  TaggedDocument(words=['to', 'understand', 'direct', 'object', 'pronouns'], tags=[48]),
#  TaggedDocument(words=['to', 'say', 'to', 'tell', 'indirect', 'object', 'pronouns'], tags=[49]),
#  TaggedDocument(words=['to', 'come'], tags=[50]),
#  TaggedDocument(words=['seasons', 'months', 'of', 'the', 'year'], tags=[51]),
#  TaggedDocument(words=['like', 'you', 'like'], tags=[52]),
#  TaggedDocument(words=['using', 'the', 'possessive'], tags=[53]),
#  TaggedDocument(words=['people', 'family', 'members', 'using', 'the', 'article', 'the'], tags=[54]),
#  TaggedDocument(words=['numbers'], tags=[55]),
#  TaggedDocument(words=['parts', 'of', 'the', 'body', 'plural', 'forms', 'of', 'the'], tags=[56]),
#  TaggedDocument(words=['clothing'], tags=[57]),
#  TaggedDocument(words=['colors', 'usage'], tags=[58]),
#  TaggedDocument(words=['in', 'the', 'home'], tags=[59]),
#  TaggedDocument(words=['days', 'of', 'the', 'week', 'today', 'tomorrow', 'yesterday'], tags=[60]),
#  TaggedDocument(words=['numbers'], tags=[61]),
#  TaggedDocument(words=['months', 'of', 'the', 'year', 'usage'], tags=[62]),
#  TaggedDocument(words=['talking', 'about', 'time'], tags=[63]),
#  TaggedDocument(words=['seasons', 'weather'], tags=[64]),
#  TaggedDocument(words=['welcome', 'nonna', 'kitchen'], tags=[65]),
#  TaggedDocument(words=['to', 'eat'], tags=[66]),
#  TaggedDocument(words=['to', 'listen', 'direct', 'object', 'pronouns'], tags=[67]),
#  TaggedDocument(words=['to', 'help', 'direct', 'object', 'pronouns'], tags=[68]),
#  TaggedDocument(words=['to', 'wait', 'direct', 'object', 'pronouns'], tags=[69]),
#  TaggedDocument(words=['to', 'hope'], tags=[70]),
#  TaggedDocument(words=['to', 'give', 'indirect', 'object', 'pronouns'], tags=[71]),
#  TaggedDocument(words=['to', 'see', 'direct', 'object', 'pronouns'], tags=[72]),
#  TaggedDocument(words=['to', 'have', 'to', 'saying', 'must'], tags=[73]),
#  TaggedDocument(words=['to', 'be', 'able', 'to', 'saying', 'can'], tags=[74]),
#  TaggedDocument(words=['to', 'take', 'to', 'be', 'required'], tags=[75]),
#  TaggedDocument(words=['to', 'hear', 'to', 'smell', 'to', 'sense'], tags=[76]),
#  TaggedDocument(words=['useful', 'tu', 'commands'], tags=[77]),
#  TaggedDocument(words=['useful', 'negative', 'tu', 'commands', 'direct', 'indirect', 'double', 'object', 'pronouns'], tags=[78]),
#  TaggedDocument(words=['words', 'of', 'love'], tags=[79]),
#  TaggedDocument(words=['talking', 'about', 'people', 'general', 'descriptions'], tags=[80]),
#  TaggedDocument(words=['describing', 'people', 'height', 'build'], tags=[81]),
#  TaggedDocument(words=['describing', 'people', 'hair'], tags=[82]),
#  TaggedDocument(words=['describing', 'people', 'positive', 'characteristics'], tags=[83]),
#  TaggedDocument(words=['describing', 'people', 'negative', 'characteristics'], tags=[84]),
#  TaggedDocument(words=['daily', 'routines', 'eating'], tags=[85]),
#  TaggedDocument(words=['daily', 'routines', 'free', 'time'], tags=[86]),
#  TaggedDocument(words=['daily', 'routines', 'housework'], tags=[87]),
#  TaggedDocument(words=['daily', 'routines', 'keeping', 'clean'], tags=[88]),
#  TaggedDocument(words=['daily', 'routines', 'sleeping'], tags=[89]),
#  TaggedDocument(words=['daily', 'routines', 'work'], tags=[90]),
#  TaggedDocument(words=['personal', 'relationships'], tags=[91]),
#  TaggedDocument(words=['everyday', 'technology'], tags=[92]),
#  TaggedDocument(words=['ordinal', 'numbers'], tags=[93]),
#  TaggedDocument(words=['uscire', 'to', 'go', 'out', 'full', 'sentence', 'examples', 'and', 'useful', 'idioms'], tags=[94]),
#  TaggedDocument(words=['divertirsi', 'to', 'have', 'fun', 'full', 'sentence', 'examples'], tags=[95]),
#  TaggedDocument(words=['lamentarsi', 'to', 'complain', 'full', 'sentence', 'examples'], tags=[96]),
#  TaggedDocument(words=['abituarsi', 'to', 'get', 'used', 'to', 'full', 'sentence', 'examples'], tags=[97]),
#  TaggedDocument(words=['rendersi', 'conto', 'to', 'realize', 'full', 'sentence', 'examples', 'fun', 'idiom'], tags=[98]),
#  TaggedDocument(words=['ordinal', 'numbers'], tags=[99]),
#  TaggedDocument(words=['intro', 'to', 'the', 'progressive', 'tense', 'are', 'verbs', 'andare', 'to', 'go', 'and', 'full', 'sentence', 'examples'], tags=[100]),
#  TaggedDocument(words=['progressive', 'tense', 'ere', 'verbs', 'leggere', 'to', 'read', 'full', 'sentence', 'examples'], tags=[101]),
#  TaggedDocument(words=['progressive', 'tense', 'ire', 'verbs', 'finire', 'to', 'finish', 'full', 'sentence', 'examples'], tags=[102]),
#  TaggedDocument(words=['progressive', 'tense', 'fare', 'to', 'make', 'to', 'do', 'full', 'sentence', 'examples'], tags=[103]),
#  TaggedDocument(words=['progressive', 'tense', 'dire', 'to', 'say', 'to', 'tell', 'full', 'sentence', 'examples'], tags=[104]),
#  TaggedDocument(words=['ordinal', 'numbers'], tags=[105]),
#  TaggedDocument(words=['riuscire', 'to', 'manage', 'to', 'full', 'sentence', 'examples'], tags=[106]),
#  TaggedDocument(words=['using', 'the', 'pronoun', 'ci', 'with', 'useful', 'examples'], tags=[107]),
#  TaggedDocument(words=['fun', 'treat', 'nonna', 'proverbs', 'grandma', 'proverbs'], tags=[108]),
#  TaggedDocument(words=['talking', 'about', 'work'], tags=[109]),
#  TaggedDocument(words=['more', 'about', 'work', 'occupations'], tags=[110]),
#  TaggedDocument(words=['more', 'work', 'professional', 'titles'], tags=[111]),
#  TaggedDocument(words=['animals'], tags=[112]),
#  TaggedDocument(words=['more', 'animals'], tags=[113]),
#  TaggedDocument(words=['parts', 'of', 'animals'], tags=[114]),
#  TaggedDocument(words=['common', 'trees', 'in', 'italy'], tags=[115]),
#  TaggedDocument(words=['parts', 'of', 'flowers'], tags=[116]),
#  TaggedDocument(words=['illnesses', 'symptoms'], tags=[117]),
#  TaggedDocument(words=['more', 'illnesses', 'symptoms'], tags=[118]),
#  TaggedDocument(words=['countries', 'nationalities'], tags=[119]),
#  TaggedDocument(words=['more', 'countries', 'nationalities'], tags=[120]),
#  TaggedDocument(words=['intro', 'to', 'the', 'passato', 'prossimo', 'are', 'verbs', 'parlare', 'full', 'sentence', 'examples'], tags=[121]),
#  TaggedDocument(words=['passato', 'prossimo', 'mangiare', 'full', 'sentence', 'examples'], tags=[122]),
#  TaggedDocument(words=['passato', 'prossimo', 'dare', 'full', 'sentence', 'examples'], tags=[123]),
#  TaggedDocument(words=['passato', 'prossimo', 'fare', 'full', 'sentence', 'examples'], tags=[124]),
#  TaggedDocument(words=['passato', 'prossimo', 'ere', 'verbs', 'vendere', 'full', 'sentence', 'examples'], tags=[125]),
#  TaggedDocument(words=['passato', 'prossimo', 'prendere', 'full', 'sentence', 'examples'], tags=[126]),
#  TaggedDocument(words=['passato', 'prossimo', 'mettere', 'full', 'sentence', 'examples'], tags=[127]),
#  TaggedDocument(words=['passato', 'prossimo', 'ire', 'verbs', 'sentire', 'full', 'sentence', 'examples'], tags=[128]),
#  TaggedDocument(words=['passato', 'prossimo', 'dire', 'full', 'sentence', 'examples'], tags=[129]),
#  TaggedDocument(words=['passato', 'prossimo', 'andare', 'full', 'sentence', 'examples'], tags=[130]),
#  TaggedDocument(words=['passato', 'prossimo', 'venire', 'full', 'sentence', 'examples'], tags=[131]),
#  TaggedDocument(words=['passato', 'prossimo', 'svegliarsi', 'full', 'sentence', 'examples'], tags=[132]),
#  TaggedDocument(words=['passato', 'prossimo', 'divertirsi', 'full', 'sentence', 'examples'], tags=[133]),
#  TaggedDocument(words=['passato', 'prossimo', 'conoscere', 'full', 'sentence', 'examples'], tags=[134]),
#  TaggedDocument(words=['using', 'the', 'pronoun', 'ne', 'useful', 'examples'], tags=[135]),
#  TaggedDocument(words=['passato', 'prossimo', 'piacere', 'mancare', 'liked', 'missed'], tags=[136]),
#  TaggedDocument(words=['welcome', 'making', 'the', 'imperfect', 'in', 'italian', 'easy'], tags=[137]),
#  TaggedDocument(words=['how', 'to', 'form', 'the', 'imperfect', 'tense', 'are', 'verbs', 'aiutare', 'full', 'sentence', 'examples'], tags=[138]),
#  TaggedDocument(words=['imperfect', 'tense', 'aspettare', 'full', 'sentence', 'examples'], tags=[139]),
#  TaggedDocument(words=['imperfect', 'tense', 'fare', 'full', 'sentence', 'examples'], tags=[140]),
#  TaggedDocument(words=['how', 'to', 'form', 'the', 'imperfect', 'tense', 'ere', 'verbs', 'avere', 'full', 'sentence', 'examples'], tags=[141]),
#  TaggedDocument(words=['imperfect', 'tense', 'sapere', 'full', 'sentence', 'examples'], tags=[142]),
#  TaggedDocument(words=['imperfect', 'tense', 'essere', 'full', 'sentence', 'examples'], tags=[143]),
#  TaggedDocument(words=['imperfect', 'tense', 'conoscere', 'full', 'sentence', 'examples'], tags=[144]),
#  TaggedDocument(words=['imperfect', 'tense', 'volere', 'full', 'sentence', 'examples'], tags=[145]),
#  TaggedDocument(words=['imperfect', 'tense', 'potere', 'full', 'sentence', 'examples'], tags=[146]),
#  TaggedDocument(words=['imperfect', 'tense', 'dovere', 'full', 'sentence', 'examples'], tags=[147]),
#  TaggedDocument(words=['how', 'to', 'form', 'the', 'imperfect', 'tense', 'ire', 'verbs', 'dormire', 'full', 'sentence', 'examples'], tags=[148]),
#  TaggedDocument(words=['imperfect', 'tense', 'dire', 'full', 'sentence', 'examples'], tags=[149]),
#  TaggedDocument(words=['imperfect', 'tense', 'stare', 'full', 'sentence', 'examples'], tags=[150]),
#  TaggedDocument(words=['imperfect', 'tense', 'pensare', 'full', 'sentence', 'examples'], tags=[151]),
#  TaggedDocument(words=['fun', 'idiomatic', 'expressions', 'using', 'the', 'pronoun', 'ci'], tags=[152]),
#  TaggedDocument(words=['travel', 'made', 'easier', 'mastering', 'the', 'formal', 'commands', 'in', 'italian'], tags=[153]),
#  TaggedDocument(words=['more', 'formal', 'command', 'practice'], tags=[154]),
#  TaggedDocument(words=['future', 'tense', 'are', 'verbs', 'full', 'sentence', 'examples'], tags=[155]),
#  TaggedDocument(words=['future', 'tense', 'ere', 'verbs', 'full', 'sentence', 'examples'], tags=[156]),
#  TaggedDocument(words=['future', 'tense', 'ire', 'verbs', 'full', 'sentence', 'examples'], tags=[157]),
#  TaggedDocument(words=['future', 'tense', 'essere', 'full', 'sentence', 'examples'], tags=[158]),
#  TaggedDocument(words=['future', 'tense', 'avere', 'full', 'sentence', 'examples'], tags=[159]),
#  TaggedDocument(words=['future', 'tense', 'dovere', 'full', 'sentence', 'examples'], tags=[160]),
#  TaggedDocument(words=['future', 'tense', 'potere', 'full', 'sentence', 'examples'], tags=[161]),
#  TaggedDocument(words=['future', 'tense', 'volere', 'full', 'sentence', 'examples'], tags=[162]),
#  TaggedDocument(words=['future', 'tense', 'fare', 'full', 'sentence', 'examples'], tags=[163]),
#  TaggedDocument(words=['future', 'tense', 'dare', 'full', 'sentence', 'examples'], tags=[164]),
#  TaggedDocument(words=['future', 'tense', 'andare', 'full', 'sentence', 'examples'], tags=[165]),
#  TaggedDocument(words=['future', 'tense', 'venire', 'full', 'sentence', 'examples'], tags=[166]),
#  TaggedDocument(words=['the', 'conditional', 'made', 'easy', 'are', 'verbs', 'parlare', 'full', 'sentence', 'examples'], tags=[167]),
#  TaggedDocument(words=['conditional', 'tense', 'ere', 'verbs', 'prendere', 'full', 'sentence', 'examples'], tags=[168]),
#  TaggedDocument(words=['conditional', 'tense', 'ire', 'verbs', 'dire', 'full', 'sentence', 'examples'], tags=[169]),
#  TaggedDocument(words=['conditional', 'of', 'essere', 'full', 'sentence', 'examples'], tags=[170]),
#  TaggedDocument(words=['conditional', 'of', 'avere', 'full', 'sentence', 'examples'], tags=[171]),
#  TaggedDocument(words=['conditional', 'of', 'dovere', 'full', 'sentence', 'examples'], tags=[172]),
#  TaggedDocument(words=['conditional', 'of', 'potere', 'full', 'sentence', 'examples'], tags=[173]),
#  TaggedDocument(words=['conditional', 'of', 'volere', 'full', 'sentence', 'examples'], tags=[174]),
#  TaggedDocument(words=['conditional', 'of', 'fare', 'full', 'sentence', 'examples'], tags=[175]),
#  TaggedDocument(words=['conditional', 'of', 'dare', 'full', 'sentence', 'examples'], tags=[176]),
#  TaggedDocument(words=['conditional', 'of', 'andare', 'full', 'sentence', 'examples'], tags=[177]),
#  TaggedDocument(words=['conditional', 'of', 'venire', 'full', 'sentence', 'examples'], tags=[178]),
#  TaggedDocument(words=['intro', 'to', 'the', 'subjunctive', 'parlare'], tags=[179]),
#  TaggedDocument(words=['subjunctive', 'of', 'prendere'], tags=[180]),
#  TaggedDocument(words=['helpful', 'examples', 'using', 'the', 'preposition'], tags=[181]),
#  TaggedDocument(words=['subjunctive', 'of', 'sentire'], tags=[182]),
#  TaggedDocument(words=['more', 'examples', 'of', 'using', 'the', 'preposition'], tags=[183]),
#  TaggedDocument(words=['subjunctive', 'of', 'essere'], tags=[184]),
#  TaggedDocument(words=['subjunctive', 'of', 'avere'], tags=[185]),
#  TaggedDocument(words=['helpful', 'examples', 'using', 'the', 'preposition', 'in'], tags=[186]),
#  TaggedDocument(words=['subjunctive', 'of', 'finire'], tags=[187]),
#  TaggedDocument(words=['subjunctive', 'of', 'fare'], tags=[188]),
#  TaggedDocument(words=['subjunctive', 'of', 'stare'], tags=[189]),
#  TaggedDocument(words=['subjunctive', 'of', 'dire'], tags=[190]),
#  TaggedDocument(words=['fun', 'useful', 'italian', 'idioms'], tags=[191]),
#  TaggedDocument(words=['nouns'], tags=[192]),
#  TaggedDocument(words=['nouns'], tags=[193]),
#  TaggedDocument(words=['nouns'], tags=[194]),
#  TaggedDocument(words=['nouns'], tags=[195]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[196]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[197]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[198]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[199]),
#  TaggedDocument(words=['expressions'], tags=[200]),
#  TaggedDocument(words=['expressions'], tags=[201]),
#  TaggedDocument(words=['expressions'], tags=[202]),
#  TaggedDocument(words=['expressions'], tags=[203]),
#  TaggedDocument(words=['verbs'], tags=[204]),
#  TaggedDocument(words=['verbs'], tags=[205]),
#  TaggedDocument(words=['verbs'], tags=[206]),
#  TaggedDocument(words=['verbs'], tags=[207]),
#  TaggedDocument(words=['nouns'], tags=[208]),
#  TaggedDocument(words=['nouns'], tags=[209]),
#  TaggedDocument(words=['nouns'], tags=[210]),
#  TaggedDocument(words=['nouns'], tags=[211]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[212]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[213]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[214]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[215]),
#  TaggedDocument(words=['expressions'], tags=[216]),
#  TaggedDocument(words=['expressions'], tags=[217]),
#  TaggedDocument(words=['expressions'], tags=[218]),
#  TaggedDocument(words=['expressions'], tags=[219]),
#  TaggedDocument(words=['verbs'], tags=[220]),
#  TaggedDocument(words=['verbs'], tags=[221]),
#  TaggedDocument(words=['verbs'], tags=[222]),
#  TaggedDocument(words=['verbs'], tags=[223]),
#  TaggedDocument(words=['nouns'], tags=[224]),
#  TaggedDocument(words=['nouns'], tags=[225]),
#  TaggedDocument(words=['nouns'], tags=[226]),
#  TaggedDocument(words=['nouns'], tags=[227]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[228]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[229]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[230]),
#  TaggedDocument(words=['adjectives', 'adverbs', 'conjunctions', 'prepositions'], tags=[231]),
#  TaggedDocument(words=['expressions'], tags=[232]),
#  TaggedDocument(words=['expressions'], tags=[233]),
#  TaggedDocument(words=['expressions'], tags=[234]),
#  TaggedDocument(words=['expressions'], tags=[235]),
#  TaggedDocument(words=['verbs'], tags=[236]),
#  TaggedDocument(words=['verbs'], tags=[237]),
#  TaggedDocument(words=['verbs'], tags=[238]),
#  TaggedDocument(words=['verbs'], tags=[239]),
#  TaggedDocument(words=['introduction', 'to', 'italian', 'verbs'], tags=[240]),
#  TaggedDocument(words=['infinitives'], tags=[241]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'tense', 'patterns'], tags=[242]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'tense', 'auitare', 'camminare'], tags=[243]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'cantare', 'domenticare'], tags=[244]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'domandare', 'imparare'], tags=[245]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'incontrare', 'nuotare'], tags=[246]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'ordinare', 'ricordare'], tags=[247]),
#  TaggedDocument(words=['are', 'verbs', 'present', 'riposare', 'trattare'], tags=[248]),
#  TaggedDocument(words=['ere', 'verbs', 'present', 'tense', 'avere', 'credere'], tags=[249]),
#  TaggedDocument(words=['ere', 'verbs', 'present', 'tense', 'dipingere', 'perdere'], tags=[250]),
#  TaggedDocument(words=['ere', 'verbs', 'present', 'tense', 'piacere', 'scendere'], tags=[251]),
#  TaggedDocument(words=['ere', 'verbs', 'present', 'tense', 'scrivere', 'volere'], tags=[252]),
#  TaggedDocument(words=['ire', 'verbs', 'present', 'tense', 'aprire', 'dormire'], tags=[253]),
#  TaggedDocument(words=['ire', 'verbs', 'present', 'tense', 'finire', 'scoprire'], tags=[254]),
#  TaggedDocument(words=['ire', 'verbs', 'present', 'tense', 'seguire', 'venire'], tags=[255]),
#  TaggedDocument(words=['passato', 'prossimo', 'tense'], tags=[256]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'aiutare', 'camminare'], tags=[257]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'cantare', 'dimenticare'], tags=[258]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'domandare', 'imparare'], tags=[259]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'incontrare', 'nuotare'], tags=[260]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'ordinare', 'ricordare'], tags=[261]),
#  TaggedDocument(words=['are', 'verbs', 'passato', 'prossimo', 'riposare', 'trattare'], tags=[262]),
#  TaggedDocument(words=['ere', 'verbs', 'passato', 'prossimo', 'avere', 'dipingere'], tags=[263]),
#  TaggedDocument(words=['ere', 'verbs', 'passato', 'prossimo', 'discutere', 'piacere'], tags=[264]),
#  TaggedDocument(words=['ere', 'verbs', 'passato', 'prossimo', 'piangere', 'scrivere'], tags=[265]),
#  TaggedDocument(words=['ere', 'verbs', 'passato', 'prossimo', 'sederesi', 'volere'], tags=[266]),
#  TaggedDocument(words=['ire', 'verbs', 'passato', 'prossimo', 'aprire', 'finire'], tags=[267]),
#  TaggedDocument(words=['ire', 'verbs', 'passato', 'prossimo', 'offrire', 'seguire'], tags=[268]),
#  TaggedDocument(words=['ire', 'verbs', 'passato', 'prossimo', 'sentire', 'venire'], tags=[269]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'pattern'], tags=[270]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'aiutare', 'andare'], tags=[271]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'arrivare', 'cantare'], tags=[272]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'cercare', 'costare'], tags=[273]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'dare', 'fare'], tags=[274]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'tense', 'fermare', 'imparare'], tags=[275]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'incontrare', 'lavorare'], tags=[276]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'mandare', 'pagare'], tags=[277]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'pensare', 'provare'], tags=[278]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'ricordare', 'sperare'], tags=[279]),
#  TaggedDocument(words=['are', 'verbs', 'imperfect', 'tense', 'stare', 'trattare'], tags=[280]),
#  TaggedDocument(words=['ere', 'verbs', 'imperfect', 'tense', 'avere', 'correre'], tags=[281]),
#  TaggedDocument(words=['ere', 'verbs', 'imperfect', 'tense', 'credere', 'godere'], tags=[282]),
#  TaggedDocument(words=['ere', 'verbs', 'imperfect', 'tense', 'leggere', 'prendere'], tags=[283]),
#  TaggedDocument(words=['ere', 'verbs', 'imperfect', 'tense', 'ridere', 'sedersi'], tags=[284]),
#  TaggedDocument(words=['ere', 'verbs', 'imperfect', 'tense', 'tenere', 'volere'], tags=[285]),
#  TaggedDocument(words=['ire', 'verbs', 'imperfect', 'tense', 'aprire', 'finire'], tags=[286]),
#  TaggedDocument(words=['ire', 'verbs', 'imperfect', 'tense', 'offrire', 'seguire'], tags=[287]),
#  TaggedDocument(words=['ire', 'verbs', 'imperfect', 'tense', 'sentire', 'venire'], tags=[288]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'patterns'], tags=[289]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'aiutare', 'cambiare'], tags=[290]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'caminare', 'costare'], tags=[291]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'dare', 'giocare'], tags=[292]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'guardare', 'lavare'], tags=[293]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'lavorare', 'pensare'], tags=[294]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'perdonare', 'ritornare'], tags=[295]),
#  TaggedDocument(words=['are', 'verbs', 'future', 'tense', 'sembrare', 'trattare'], tags=[296]),
#  TaggedDocument(words=['ere', 'verbs', 'future', 'tense', 'avere', 'dovere'], tags=[297]),
#  TaggedDocument(words=['ere', 'verbs', 'future', 'tense', 'essere', 'sapere'], tags=[298]),
#  TaggedDocument(words=['ere', 'verbs', 'future', 'tense', 'scegliere', 'volere'], tags=[299]),
#  TaggedDocument(words=['ire', 'verbs', 'future', 'tense', 'aprire', 'salire'], tags=[300]),
#  TaggedDocument(words=['ire', 'verbs', 'future', 'tense', 'scomparire', 'venire'], tags=[301]),
#  TaggedDocument(words=['are', 'verbs', 'gerundive', 'pattern'], tags=[302]),
#  TaggedDocument(words=['ere', 'verbs', 'gerundive', 'pattern'], tags=[303]),
#  TaggedDocument(words=['ire', 'verbs', 'gerundive', 'pattern'], tags=[304]),
#  TaggedDocument(words=['are', 'verbs', 'past', 'participle', 'patterns'], tags=[305]),
#  TaggedDocument(words=['ere', 'verbs', 'past', 'participle', 'patterns'], tags=[306]),
#  TaggedDocument(words=['ire', 'verbs', 'past', 'participle', 'patterns'], tags=[307]),
#  TaggedDocument(words=['activities'], tags=[308]),
#  TaggedDocument(words=['nouns'], tags=[309]),
#  TaggedDocument(words=['plural', 'nouns'], tags=[310]),
#  TaggedDocument(words=['adjectives'], tags=[311]),
#  TaggedDocument(words=['verbs'], tags=[312]),
#  TaggedDocument(words=['numbers'], tags=[313]),
#  TaggedDocument(words=['large', 'numbers'], tags=[314]),
#  TaggedDocument(words=['adverbs'], tags=[315]),
#  TaggedDocument(words=['conjunctions'], tags=[316]),
#  TaggedDocument(words=['prepositions'], tags=[317]),
#  TaggedDocument(words=['expressions'], tags=[318]),
#  TaggedDocument(words=['days', 'months'], tags=[319]),
#  TaggedDocument(words=['countries'], tags=[320]),
#  TaggedDocument(words=['verbs', 'ii'], tags=[321]),
#  TaggedDocument(words=['adjectives', 'ii'], tags=[322]),
#  TaggedDocument(words=['expressions', 'ii'], tags=[323]),
#  TaggedDocument(words=['nouns', 'ii'], tags=[324]),
#  TaggedDocument(words=['more', 'verbs'], tags=[325]),
#  TaggedDocument(words=['more', 'adverbs'], tags=[326]),
#  TaggedDocument(words=['travel', 'terms'], tags=[327]),
#  TaggedDocument(words=['more', 'expressions'], tags=[328]),
#  TaggedDocument(words=['romantic', 'italian', 'phrases', 'my', 'love'], tags=[329]),
#  TaggedDocument(words=['romantic', 'italian', 'phrases', 'want', 'you'], tags=[330]),
#  TaggedDocument(words=['italian', 'love', 'proverbs'], tags=[331]),
#  TaggedDocument(words=['romantic', 'italian', 'phrases', 'love', 'your', 'eyes'], tags=[332]),
#  TaggedDocument(words=['greetings'], tags=[333]),
#  TaggedDocument(words=['personal', 'information'], tags=[334]),
#  TaggedDocument(words=['help', 'directions'], tags=[335]),
#  TaggedDocument(words=['well', 'wishes'], tags=[336]),
#  TaggedDocument(words=['restaurants'], tags=[337]),
#  TaggedDocument(words=['shopping'], tags=[338]),
#  TaggedDocument(words=['pick', 'up', 'lines'], tags=[339]),
#  TaggedDocument(words=['swearing'], tags=[340]),
#  TaggedDocument(words=['what', 'mess'], tags=[341]),
#  TaggedDocument(words=['are', 'you', 'nuts'], tags=[342]),
#  TaggedDocument(words=['don', 'give', 'you', 'know', 'what'], tags=[343]),
#  TaggedDocument(words=['cut', 'it', 'out'], tags=[344]),
#  TaggedDocument(words=['saying', 'big', 'time'], tags=[345]),
#  TaggedDocument(words=['messing', 'up'], tags=[346]),
#  TaggedDocument(words=['uh', 'oh', 'we', 're', 'in', 'trouble'], tags=[347]),
#  TaggedDocument(words=['can', 'take', 'it', 'anymore'], tags=[348]),
#  TaggedDocument(words=['talking', 'about', 'money', 'she', 'spender'], tags=[349]),
#  TaggedDocument(words=['that', 'bunch', 'of', 'baloney'], tags=[350]),
#  TaggedDocument(words=['feeling', 'great'], tags=[351]),
#  TaggedDocument(words=['feeling', 'not', 'so', 'good'], tags=[352]),
#  TaggedDocument(words=['so', 'angry'], tags=[353]),
#  TaggedDocument(words=['how', 'annoying'], tags=[354]),
#  TaggedDocument(words=['more', 'funny', 'italian', 'essentials'], tags=[355]),
#  TaggedDocument(words=['eh', 'goombah'], tags=[356]),
#  TaggedDocument(words=['he', 'friend', 'of', 'ours'], tags=[357]),
#  TaggedDocument(words=['meet', 'the', 'family'], tags=[358]),
#  TaggedDocument(words=['getting', 'pinched', 'keeping', 'it', 'zipped'], tags=[359]),
#  TaggedDocument(words=['time', 'to', 'water', 'the', 'fava', 'beans'], tags=[360]),
#  TaggedDocument(words=['gangsters', 'have', 'mothers', 'too'], tags=[361]),
#  TaggedDocument(words=['it', 'easy', 'money'], tags=[362]),
#  TaggedDocument(words=['take', 'your', 'gun', 'with', 'you'], tags=[363]),
#  TaggedDocument(words=['get', 'the', 'shovels'], tags=[364]),
#  TaggedDocument(words=['all', 'hell', 'broken', 'loose'], tags=[365]),
#  TaggedDocument(words=['introduction'], tags=[366]),
#  TaggedDocument(words=['lesson', 'basics'], tags=[367]),
#  TaggedDocument(words=['lesson', 'basic', 'phrases'], tags=[368]),
#  TaggedDocument(words=['lesson', 'transportation', 'nouns'], tags=[369]),
#  TaggedDocument(words=['lesson', 'transportation', 'phrases'], tags=[370]),
#  TaggedDocument(words=['lesson', 'money'], tags=[371]),
#  TaggedDocument(words=['lesson', 'hotel'], tags=[372]),
#  TaggedDocument(words=['lesson', 'important', 'words'], tags=[373]),
#  TaggedDocument(words=['lesson', 'directions'], tags=[374]),
#  TaggedDocument(words=['lesson', 'numbers'], tags=[375]),
#  TaggedDocument(words=['lesson', 'more', 'numbers'], tags=[376]),
#  TaggedDocument(words=['lesson', 'big', 'numbers'], tags=[377]),
#  TaggedDocument(words=['lesson', 'very', 'big', 'numbers'], tags=[378]),
#  TaggedDocument(words=['lesson', 'at', 'the', 'restaurant'], tags=[379]),
#  TaggedDocument(words=['lesson', 'shopping'], tags=[380]),
#  TaggedDocument(words=['lesson', 'time', 'general'], tags=[381]),
#  TaggedDocument(words=['lesson', 'time', 'of', 'day'], tags=[382]),
#  TaggedDocument(words=['lesson', 'questions'], tags=[383]),
#  TaggedDocument(words=['lesson', 'shops'], tags=[384]),
#  TaggedDocument(words=['lesson', 'nouns'], tags=[385]),
#  TaggedDocument(words=['lesson', 'adjectives', 'and', 'adverbs'], tags=[386]),
#  TaggedDocument(words=['lesson', 'verbs'], tags=[387]),
#  TaggedDocument(words=['lesson', 'prepositions'], tags=[388]),
#  TaggedDocument(words=['lesson', 'prepostional', 'pronouns'], tags=[389]),
#  TaggedDocument(words=['lesson', 'possesive', 'adjectives'], tags=[390]),
#  TaggedDocument(words=['lesson', 'conjunctions', 'and', 'similar', 'words'], tags=[391]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'general'], tags=[392]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'negative'], tags=[393]),
#  TaggedDocument(words=['lesson', 'forming', 'questions'], tags=[394]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'general'], tags=[395]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'transportation'], tags=[396]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'money'], tags=[397]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'hotel'], tags=[398]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'getting', 'around'], tags=[399]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'directions'], tags=[400]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'conversation'], tags=[401]),
#  TaggedDocument(words=['lesson', 'sentences', 'and', 'phrases', 'internet'], tags=[402]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'essere', 'to', 'be', 'present', 'tense'], tags=[403]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'avere', 'to', 'have', 'present', 'tense'], tags=[404]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'are', 'ending', 'present', 'tense'], tags=[405]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ere', 'ending', 'present', 'tense'], tags=[406]),
#  TaggedDocument(words=['introduction'], tags=[407]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ire', 'endings', 'present', 'tense'], tags=[408]),
#  TaggedDocument(words=['lesson', 'irregular', 'ire', 'verbs', 'which', 'use', 'the', 'isc', 'endings'], tags=[409]),
#  TaggedDocument(words=['lesson', 'the', 'verbs', 'to', 'live', 'and', 'to', 'reside'], tags=[410]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verbs', 'with', 'are', 'ending', 'future', 'tense'], tags=[411]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ere', 'ending', 'future', 'tense'], tags=[412]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ire', 'ending', 'future', 'tense'], tags=[413]),
#  TaggedDocument(words=['lesson', 'speaking', 'with', 'the', 'infinitive', 'of', 'verb'], tags=[414]),
#  TaggedDocument(words=['lesson', 'speaking', 'in', 'the', 'past', 'tense'], tags=[415]),
#  TaggedDocument(words=['lesson', 'speaking', 'in', 'the', 'past', 'tense'], tags=[416]),
#  TaggedDocument(words=['lesson', 'verbs', 'that', 'use', 'essere', 'past', 'tense'], tags=[417]),
#  TaggedDocument(words=['lesson', 'infinitve', 'verb', 'forms'], tags=[418]),
#  TaggedDocument(words=['lesson', 'more', 'infinitives'], tags=[419]),
#  TaggedDocument(words=['lesson', 'the', 'telephone'], tags=[420]),
#  TaggedDocument(words=['lesson', 'practice', 'with', 'the', 'past', 'tense'], tags=[421]),
#  TaggedDocument(words=['lesson', 'more', 'past', 'participles'], tags=[422]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'essere', 'imperfect', 'tense'], tags=[423]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'avere', 'imperfect', 'tense'], tags=[424]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'are', 'ending', 'imperfect', 'tense'], tags=[425]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ere', 'ending', 'imperfect', 'tense'], tags=[426]),
#  TaggedDocument(words=['lesson', 'typical', 'regular', 'verb', 'with', 'ire', 'ending', 'imperfect', 'tense'], tags=[427]),
#  TaggedDocument(words=['lesson', 'some', 'common', 'verbs', 'in', 'the', 'imperfect', 'tense'], tags=[428]),
#  TaggedDocument(words=['lesson', 'some', 'important', 'concepts'], tags=[429]),
#  TaggedDocument(words=['lesson', 'more', 'important', 'concepts'], tags=[430]),
#  TaggedDocument(words=['lesson', 'useful', 'singular', 'verb', 'forms', 'in', 'sentences', 'present', 'tense'], tags=[431]),
#  TaggedDocument(words=['lesson', 'useful', 'plural', 'verb', 'forms', 'in', 'sentences', 'present', 'tense'], tags=[432]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'to', 'go', 'present', 'tense'], tags=[433]),
#  TaggedDocument(words=['lesson', 'using', 'direct', 'object', 'pronouns', 'in', 'sentences'], tags=[434]),
#  TaggedDocument(words=['lesson', 'more', 'direct', 'object', 'pronouns'], tags=[435]),
#  TaggedDocument(words=['lesson', 'using', 'indirect', 'object', 'pronouns', 'in', 'sentences'], tags=[436]),
#  TaggedDocument(words=['lesson', 'direct', 'and', 'indirect', 'object', 'prouns', 'together'], tags=[437]),
#  TaggedDocument(words=['lesson', 'pronouns', 'in', 'negative', 'sentences'], tags=[438]),
#  TaggedDocument(words=['lesson', 'the', 'car'], tags=[439]),
#  TaggedDocument(words=['lesson', 'sentences', 'with', 'important', 'words', 'and', 'concepts'], tags=[440]),
#  TaggedDocument(words=['lesson', 'more', 'sentences', 'with', 'important', 'words', 'and', 'concepts'], tags=[441]),
#  TaggedDocument(words=['introduction'], tags=[442]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'to', 'be', 'future', 'tense'], tags=[443]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'to', 'have', 'future', 'tense'], tags=[444]),
#  TaggedDocument(words=['lesson', 'the', 'irregular', 'verb', 'to', 'go', 'future', 'tense'], tags=[445]),
#  TaggedDocument(words=['lesson', 'other', 'irregular', 'future', 'verb', 'stems'], tags=[446]),
#  TaggedDocument(words=['lesson', 'practice', 'with', 'the', 'future', 'are', 'ere', 'and', 'ire', 'verbs'], tags=[447]),
#  TaggedDocument(words=['lesson', 'days', 'of', 'the', 'week'], tags=[448]),
#  TaggedDocument(words=['lesson', 'months', 'of', 'the', 'year'], tags=[449]),
#  TaggedDocument(words=['lesson', 'at', 'the', 'doctor', 'office'], tags=[450]),
#  TaggedDocument(words=['lesson', 'at', 'the', 'dinner', 'table'], tags=[451]),
#  TaggedDocument(words=['lesson', 'reflexive', 'reciprocal', 'verbs'], tags=[452]),
#  TaggedDocument(words=['lesson', 'speaking', 'about', 'the', 'past', 'with', 'reflexive', 'verbs'], tags=[453]),
#  TaggedDocument(words=['lesson', 'reflexive', 'verbs', 'negative'], tags=[454]),
#  TaggedDocument(words=['lesson', 'clothes'], tags=[455]),
#  TaggedDocument(words=['lesson', 'colors'], tags=[456]),
#  TaggedDocument(words=['lesson', 'ordinal', 'numbers'], tags=[457]),
#  TaggedDocument(words=['lesson', 'technology', 'today'], tags=[458]),
#  TaggedDocument(words=['lesson', 'more', 'computer', 'vocabulary'], tags=[459]),
#  TaggedDocument(words=['lesson', 'technology', 'in', 'action'], tags=[460]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'fare', 'and', 'its', 'idiomatic', 'expressions'], tags=[461]),
#  TaggedDocument(words=['lesson', 'the', 'present', 'conditional', 'tense', 'with', 'are', 'verbs'], tags=[462]),
#  TaggedDocument(words=['lesson', 'the', 'present', 'conditional', 'tense', 'with', 'ere', 'verbs'], tags=[463]),
#  TaggedDocument(words=['lesson', 'the', 'present', 'conditional', 'tense', 'with', 'ire', 'verbs'], tags=[464]),
#  TaggedDocument(words=['lesson', 'the', 'present', 'conditional', 'tense', 'with', 'irregular', 'verbs'], tags=[465]),
#  TaggedDocument(words=['lesson', 'meanings', 'of', 'dovere', 'potere', 'volere', 'in', 'the', 'conditional'], tags=[466]),
#  TaggedDocument(words=['lesson', 'the', 'different', 'meanings', 'of', 'the', 'verb', 'to', 'know'], tags=[467]),
#  TaggedDocument(words=['lesson', 'use', 'of', 'the', 'irregular', 'verb', 'piacere'], tags=[468]),
#  TaggedDocument(words=['lesson', 'general', 'greeting', 'expressions', 'and', 'others', 'requiring', 'the', 'verb', 'stare'], tags=[469]),
#  TaggedDocument(words=['lesson', 'the', 'gerund', 'and', 'the', 'role', 'of', 'stare'], tags=[470]),
#  TaggedDocument(words=['lesson', 'use', 'of', 'buono', 'bello', 'bravo', 'and', 'their', 'placement', 'in', 'the', 'sentence'], tags=[471]),
#  TaggedDocument(words=['lesson', 'common', 'expressions'], tags=[472]),
#  TaggedDocument(words=['lesson', 'several', 'meanings', 'of', 'the', 'verb', 'dovere'], tags=[473]),
#  TaggedDocument(words=['lesson', 'the', 'verb', 'dare', 'and', 'its', 'idioms'], tags=[474]),
#  TaggedDocument(words=['lesson', 'the', 'partitive'], tags=[475]),
#  TaggedDocument(words=['conversation'], tags=[476]),
#  TaggedDocument(words=['numbers'], tags=[477]),
#  TaggedDocument(words=['relations'], tags=[478]),
#  TaggedDocument(words=['directions'], tags=[479]),
#  TaggedDocument(words=['rooms', 'buildings'], tags=[480]),
#  TaggedDocument(words=['transport'], tags=[481]),
#  TaggedDocument(words=['places'], tags=[482]),
#  TaggedDocument(words=['vegetables', 'fruits'], tags=[483]),
#  TaggedDocument(words=['food', 'drink'], tags=[484]),
#  TaggedDocument(words=['nouns'], tags=[485]),
#  TaggedDocument(words=['clothing'], tags=[486]),
#  TaggedDocument(words=['sports'], tags=[487]),
#  TaggedDocument(words=['emergencies'], tags=[488]),
#  TaggedDocument(words=['time'], tags=[489]),
#  TaggedDocument(words=['colours'], tags=[490]),
#  TaggedDocument(words=['countries', 'continents'], tags=[491]),
#  TaggedDocument(words=['restaurant'], tags=[492]),
#  TaggedDocument(words=['in', 'the', 'kitchen'], tags=[493]),
#  TaggedDocument(words=['in', 'the', 'bathroom'], tags=[494]),
#  TaggedDocument(words=['adjectives'], tags=[495]),
#  TaggedDocument(words=['verbs'], tags=[496]),
#  TaggedDocument(words=['animals'], tags=[497]),
#  TaggedDocument(words=['phrases'], tags=[498]),
#  TaggedDocument(words=['introduction', 'please', 'thank', 'you', 'hello', 'good', 'bye'], tags=[499]),
#  TaggedDocument(words=['greetings', 'how', 'are', 'you'], tags=[500]),
#  TaggedDocument(words=['introductions', 'my', 'name', 'is'], tags=[501]),
#  TaggedDocument(words=['numbers'], tags=[502]),
#  TaggedDocument(words=['useful', 'restaurant', 'vocab'], tags=[503]),
#  TaggedDocument(words=['getting', 'table', 'ordering', 'food'], tags=[504]),
#  TaggedDocument(words=['see', 'what', 'you', 've', 'learned', 'restaurant', 'conversation'], tags=[505]),
#  TaggedDocument(words=['numbers'], tags=[506]),
#  TaggedDocument(words=['asking', 'directions', 'where', 'is', 'the', 'duomo'], tags=[507]),
#  TaggedDocument(words=['getting', 'around', 'excuse', 'me'], tags=[508]),
#  TaggedDocument(words=['more', 'directions', 'where', 'is', 'the', 'hospital'], tags=[509]),
#  TaggedDocument(words=['subway', 'survival', 'when', 'does', 'the', 'train', 'leave'], tags=[510]),
#  TaggedDocument(words=['subway', 'train', 'survival', 'buying', 'ticket', 'how', 'much', 'is', 'it'], tags=[511]),
#  TaggedDocument(words=['subway', 'train', 'survival', 'from', 'which', 'track'], tags=[512]),
#  TaggedDocument(words=['saying', 'need', 'asking', 'for', 'help'], tags=[513]),
#  TaggedDocument(words=['asking', 'do', 'you', 'speak', 'english'], tags=[514]),
#  TaggedDocument(words=['useful', 'phrases', 'where', 'can', 'find', 'the', 'bathroom', 'good', 'restaurant', 'etc'], tags=[515]),
#  TaggedDocument(words=['greetings', 'please', 'thank', 'you'], tags=[516]),
#  TaggedDocument(words=['meeting', 'people', 'my', 'name', 'is', 'what', 'is', 'your', 'name'], tags=[517]),
#  TaggedDocument(words=['asking', 'where', 'are', 'you', 'from', 'from'], tags=[518]),
#  TaggedDocument(words=['more', 'about', 'you', 'saying', 'italian', 'american', 'single'], tags=[519]),
#  TaggedDocument(words=['introductions', 'this', 'is', 'my', 'his', 'her', 'name', 'is'], tags=[520]),
#  TaggedDocument(words=['at', 'the', 'restaurant', 'getting', 'table'], tags=[521]),
#  TaggedDocument(words=['ordering', 'meal', 'saying', 'can', 'have'], tags=[522]),
#  TaggedDocument(words=['excuse', 'me', 'where', 'is'], tags=[523]),
#  TaggedDocument(words=['where', 'can', 'find', 'asking', 'directions'], tags=[524]),
#  TaggedDocument(words=['at', 'the', 'hotel'], tags=[525]),
#  TaggedDocument(words=['more', 'at', 'the', 'restaurant', 'may', 'have'], tags=[526]),
#  TaggedDocument(words=['at', 'the', 'airport'], tags=[527]),
#  TaggedDocument(words=['at', 'the', 'train', 'station'], tags=[528]),
#  TaggedDocument(words=['intro', 'at', 'the', 'bar', 'with', 'sandro', 'part'], tags=[529]),
#  TaggedDocument(words=['at', 'the', 'bar', 'with', 'sandro', 'part'], tags=[530]),
#  TaggedDocument(words=['getting', 'ready', 'to', 'travel', 'by', 'train', 'part'], tags=[531]),
#  TaggedDocument(words=['getting', 'ready', 'to', 'travel', 'by', 'train', 'part'], tags=[532]),
#  TaggedDocument(words=['at', 'the', 'train', 'station', 'purchasing', 'ticket'], tags=[533]),
#  TaggedDocument(words=['useful', 'shopping', 'phrases'], tags=[534]),
#  TaggedDocument(words=['where', 'to', 'shop', 'the', 'market', 'the', 'bakery', 'the', 'clothing', 'store'], tags=[535]),
#  TaggedDocument(words=['more', 'about', 'shopping', 'tip', 'from', 'serena'], tags=[536]),
#  TaggedDocument(words=['shopping', 'experience', 'in', 'florence', 'trying', 'on', 'clothing'], tags=[537]),
#  TaggedDocument(words=['traveling', 'by', 'air'], tags=[538]),
#  TaggedDocument(words=['air', 'travel', 'phrases', 'your', 'turn', 'to', 'practice'], tags=[539]),
#  TaggedDocument(words=['holidays', 'by', 'the', 'sea', 'where', 'should', 'we', 'stay'], tags=[540]),
#  TaggedDocument(words=['checking', 'in', 'at', 'the', 'hotel'], tags=[541]),
#  TaggedDocument(words=['getting', 'ready', 'for', 'day', 'at', 'the', 'sea'], tags=[542]),
#  TaggedDocument(words=['things', 'to', 'do', 'at', 'the', 'sea'], tags=[543]),
#  TaggedDocument(words=['back', 'at', 'the', 'hotel', 'useful', 'phrases'], tags=[544]),
#  TaggedDocument(words=['going', 'into', 'town', 'getting', 'directions'], tags=[545]),
#  TaggedDocument(words=['travel', 'adventures', 'driving', 'in', 'italy'], tags=[546]),
#  TaggedDocument(words=['renting', 'car', 'useful', 'phrases', 'vocab'], tags=[547]),
#  TaggedDocument(words=['renting', 'car', 'your', 'turn', 'to', 'try'], tags=[548]),
#  TaggedDocument(words=['more', 'useful', 'phrases', 'vocab', 'for', 'driving', 'in', 'italy'], tags=[549]),
#  TaggedDocument(words=['when', 'things', 'don', 'go', 'quite', 'right', 'rental', 'car', 'complaints'], tags=[550]),
#  TaggedDocument(words=['objects', 'and', 'people', 'in', 'classroom', 'school', 'in', 'italian'], tags=[551]),
#  TaggedDocument(words=['office', 'vocabulary', 'in', 'italian'], tags=[552]),
#  TaggedDocument(words=['transportation', 'in', 'italian'], tags=[553]),
#  TaggedDocument(words=['parts', 'of', 'the', 'body', 'in', 'italian'], tags=[554]),
#  TaggedDocument(words=['the', 'weather', 'in', 'italian'], tags=[555]),
#  TaggedDocument(words=['clothing', 'and', 'accessories', 'italian'], tags=[556]),
#  TaggedDocument(words=['adjectives', 'in', 'italian'], tags=[557]),
#  TaggedDocument(words=['verbs', 'in', 'italian'], tags=[558]),
#  TaggedDocument(words=['adverbs', 'in', 'italian'], tags=[559]),
#  TaggedDocument(words=['prepositions', 'of', 'location', 'and', 'direction', 'in', 'italian'], tags=[560]),
#  TaggedDocument(words=['colors', 'in', 'italian'], tags=[561]),
#  TaggedDocument(words=['the', 'family', 'in', 'italian'], tags=[562]),
#  TaggedDocument(words=['places', 'in', 'italian'], tags=[563]),
#  TaggedDocument(words=['food', 'and', 'drinks', 'in', 'italian'], tags=[564]),
#  TaggedDocument(words=['sports', 'and', 'leisure', 'in', 'italian'], tags=[565]),
#  TaggedDocument(words=['professions', 'in', 'italian'], tags=[566]),
#  TaggedDocument(words=['animals', 'in', 'italian'], tags=[567]),
#  TaggedDocument(words=['insects', 'in', 'italian'], tags=[568]),
#  TaggedDocument(words=['the', 'nature', 'vocabulary', 'in', 'italian'], tags=[569]),
#  TaggedDocument(words=['seasons', 'in', 'italian'], tags=[570]),
#  TaggedDocument(words=['musical', 'instruments', 'in', 'italian'], tags=[571]),
#  TaggedDocument(words=['shapes', 'in', 'italian'], tags=[572]),
#  TaggedDocument(words=['the', 'house', 'vocabulary', 'in', 'italian'], tags=[573]),
#  TaggedDocument(words=['laundry', 'vocabulary', 'in', 'italian'], tags=[574]),
#  TaggedDocument(words=['toys', 'in', 'italian'], tags=[575]),
#  TaggedDocument(words=['special', 'days', 'in', 'italian'], tags=[576]),
#  TaggedDocument(words=['daily', 'activities', 'in', 'italian'], tags=[577]),
#  TaggedDocument(words=['garage', 'and', 'garden', 'tools'], tags=[578]),
#  TaggedDocument(words=['health', 'and', 'emergency', 'vocabulary', 'in', 'italian'], tags=[579]),
#  TaggedDocument(words=['communication', 'vocabulary', 'in', 'italian'], tags=[580]),
#  TaggedDocument(words=['farm', 'vocabulary', 'in', 'italian'], tags=[581]),
#  TaggedDocument(words=['useful', 'italian', 'words', 'and', 'expressions'], tags=[582]),
#  TaggedDocument(words=['numbers', 'in', 'italian', 'counting', 'in', 'italian'], tags=[583]),
#  TaggedDocument(words=['days', 'of', 'the', 'week', 'in', 'italian'], tags=[584]),
#  TaggedDocument(words=['months', 'of', 'the', 'year', 'in', 'italian'], tags=[585]),
#  TaggedDocument(words=['asking', 'and', 'telling', 'time', 'in', 'italian'], tags=[586]),
#  TaggedDocument(words=['basic', 'exchanges', 'in', 'italian'], tags=[587]),
#  TaggedDocument(words=['english', 'to', 'italian', 'intro'], tags=[588]),
#  TaggedDocument(words=['courtesies', 'please'], tags=[589]),
#  TaggedDocument(words=['thank', 'you', 'you', 'are', 'welcome', 'you', 'are', 'very', 'kind'], tags=[590]),
#  TaggedDocument(words=['excuse', 'me', 'good', 'night'], tags=[591]),
#  TaggedDocument(words=['how', 'are', 'you', 'hello', 'goodbye'], tags=[592]),
#  TaggedDocument(words=['for', 'better', 'understanding'], tags=[593]),
#  TaggedDocument(words=['yes', 'no', 'good', 'bad'], tags=[594]),
#  TaggedDocument(words=['understand', 'do', 'not', 'understand', 'do', 'you', 'understand'], tags=[595]),
#  TaggedDocument(words=['don', 'speak', 'please', 'call', 'somebody', 'who', 'can', 'speak'], tags=[596]),
# ...
#  TaggedDocument(words=['systemic', 'risk'], tags=[795]),
#  TaggedDocument(words=['outsourcing', 'productive', 'capacity'], tags=[796]),
#  TaggedDocument(words=['protest', 'and', 'industrial', 'takeover'], tags=[797]),
#  TaggedDocument(words=['fixing', 'the', 'financial', 'crisis'], tags=[798]),
#  TaggedDocument(words=['marketing', 'political', 'campaigns'], tags=[799]),
#  TaggedDocument(words=['the', 'energy', 'corporations'], tags=[800]),
#  TaggedDocument(words=['objectives', 'in', 'vietnam'], tags=[801]),
#  TaggedDocument(words=['the', 'threat', 'of', 'independent', 'development'], tags=[802]),
#  TaggedDocument(words=['crisis', 'of', 'democracy'], tags=[803]),
#  TaggedDocument(words=['as', 'victim'], tags=[804]),
#  TaggedDocument(words=['social', 'movements'], tags=[805]),
#  TaggedDocument(words=['the', 'nuclear', 'crisis'], tags=[806]),
#  TaggedDocument(words=['nuclear', 'resolutions'], tags=[807]),
#  TaggedDocument(words=['why', 'didn', 'the', 'veto', 'the', 'resolution'], tags=[808]),
#  TaggedDocument(words=['how', 'can', 'we', 'create', 'positive', 'change'], tags=[809]),
#  TaggedDocument(words=['latin', 'american', 'independence'], tags=[810]),
#  TaggedDocument(words=['national', 'security', 'states'], tags=[811]),
#  TaggedDocument(words=['the', 'drug', 'war'], tags=[812]),
#  TaggedDocument(words=['criminalization', 'of', 'black', 'life'], tags=[813]),
#  TaggedDocument(words=['why', 'did', 'the', 'banks', 'need', 'the', 'bailout'], tags=[814]),
#  TaggedDocument(words=['has', 'capitalism', 'failed'], tags=[815]),
#  TaggedDocument(words=['wage', 'labor'], tags=[816]),
#  TaggedDocument(words=['organizing', 'people'], tags=[817]),
#  TaggedDocument(words=['how', 'can', 'we', 'fight', 'for', 'change'], tags=[818]),
#  TaggedDocument(words=['is', 'honduras', 'going', 'into', 'civil', 'war'], tags=[819]),
#  TaggedDocument(words=['how', 'can', 'we', 'support', 'radical', 'labor', 'movement'], tags=[820]),
#  TaggedDocument(words=['can', 'the', 'internet', 'affect', 'participation', 'in', 'democracy'], tags=[821]),
#  TaggedDocument(words=['europe', 'democracy', 'deficit'], tags=[822]),
#  TaggedDocument(words=['is', 'violence', 'necessary', 'for', 'change', 'in', 'the'], tags=[823]),
#  TaggedDocument(words=['the', 'gaza', 'freedom', 'march'], tags=[824]),
#  TaggedDocument(words=['third', 'party'], tags=[825]),
#  TaggedDocument(words=['why', 'couldn', 'have', 'been', 'an', 'inside', 'job'], tags=[826]),
#  TaggedDocument(words=['recent', 'trip', 'to', 'venezuela'], tags=[827]),
#  TaggedDocument(words=['government', 'being', 'christ', 'like'], tags=[828]),
#  TaggedDocument(words=['human', 'rights', 'in', 'iran'], tags=[829]),
#  TaggedDocument(words=['assessing', 'the', 'situation', 'in', 'iran'], tags=[830]),
#  TaggedDocument(words=['charges', 'against', 'iran'], tags=[831]),
#  TaggedDocument(words=['nuclear', 'resolution'], tags=[832]),
#  TaggedDocument(words=['nuclear', 'weapons', 'programs'], tags=[833]),
#  TaggedDocument(words=['anti', 'missile', 'systems'], tags=[834]),
#  TaggedDocument(words=['instituting', 'nuclear', 'free', 'zone', 'in', 'iran'], tags=[835]),
#  TaggedDocument(words=['the', 'sixth', 'nuclear', 'free', 'zone'], tags=[836]),
#  TaggedDocument(words=['solutions', 'in', 'afghanistan'], tags=[837]),
#  TaggedDocument(words=['border', 'control'], tags=[838]),
#  TaggedDocument(words=['student', 'activism', 'in', 'iran'], tags=[839]),
#  TaggedDocument(words=['iran', 'russian', 'relations'], tags=[840]),
#  TaggedDocument(words=['israel', 'and', 'palestine'], tags=[841]),
#  TaggedDocument(words=['iranian', 'support'], tags=[842]),
#  TaggedDocument(words=['relaxing', 'tensions', 'in', 'iran'], tags=[843]),
#  TaggedDocument(words=['the', 'basic', 'principle', 'of', 'the', 'government'], tags=[844]),
#  TaggedDocument(words=['the', 'concept', 'of', 'the', 'wealth', 'of', 'nations'], tags=[845]),
#  TaggedDocument(words=['private', 'tyranny'], tags=[846]),
#  TaggedDocument(words=['the', 'threat', 'of', 'corporate', 'power'], tags=[847]),
#  TaggedDocument(words=['corporate', 'totalitarianism'], tags=[848]),
#  TaggedDocument(words=['risk', 'analysis'], tags=[849]),
#  TaggedDocument(words=['deregulated', 'and', 'subsidized'], tags=[850]),
#  TaggedDocument(words=['the', 'health', 'of', 'the', 'economy'], tags=[851]),
#  TaggedDocument(words=['labor', 'unions'], tags=[852]),
#  TaggedDocument(words=['international', 'labor', 'standards'], tags=[853]),
#  TaggedDocument(words=['excess', 'capital', 'and', 'capacity'], tags=[854]),
#  TaggedDocument(words=['the', 'free', 'market'], tags=[855]),
#  TaggedDocument(words=['free', 'trade'], tags=[856]),
#  TaggedDocument(words=['market', 'interference'], tags=[857]),
#  TaggedDocument(words=['tough', 'love', 'policy'], tags=[858]),
#  TaggedDocument(words=['rights', 'of', 'the', 'poor'], tags=[859]),
#  TaggedDocument(words=['crafting', 'terminology', 'national', 'interest', 'and', 'special', 'interest'], tags=[860]),
#  TaggedDocument(words=['debasing', 'language', 'and', 'meaning'], tags=[861]),
#  TaggedDocument(words=['development', 'of', 'the', 'meaning', 'of', 'terrorism'], tags=[862]),
#  TaggedDocument(words=['terrorism', 'as', 'political', 'tool'], tags=[863]),
#  TaggedDocument(words=['analyzing', 'terrorism', 'tactics'], tags=[864]),
#  TaggedDocument(words=['justification', 'vs', 'explanation'], tags=[865]),
#  TaggedDocument(words=['engineering', 'educational', 'institutions'], tags=[866]),
#  TaggedDocument(words=['propaganda'], tags=[867]),
#  TaggedDocument(words=['experts', 'in', 'legitimation'], tags=[868]),
#  TaggedDocument(words=['the', 'media', 'shape', 'of', 'perception'], tags=[869]),
#  TaggedDocument(words=['control', 'of', 'capital'], tags=[870]),
#  TaggedDocument(words=['noam', 'chomsky', 'in', 'the', 'public', 'eye'], tags=[871]),
#  TaggedDocument(words=['writing', 'without', 'anger'], tags=[872]),
#  TaggedDocument(words=['social', 'movements', 'of', 'the'], tags=[873]),
#  TaggedDocument(words=['efforts', 'to', 'restore', 'order', 'after', 'social', 'movements'], tags=[874]),
#  TaggedDocument(words=['the', 'vietnam', 'war'], tags=[875]),
#  TaggedDocument(words=['the', 'left'], tags=[876]),
#  TaggedDocument(words=['palestine', 'two', 'state', 'solution'], tags=[877]),
#  TaggedDocument(words=['racial', 'attitudes', 'and', 'stereotypes'], tags=[878]),
#  TaggedDocument(words=['anti', 'semitism'], tags=[879]),
#  TaggedDocument(words=['effects', 'of', 'the', 'holocaust'], tags=[880]),
#  TaggedDocument(words=['the', 'american', 'liberal', 'community'], tags=[881]),
#  TaggedDocument(words=['anthony', 'lewis', 'defense', 'of', 'the', 'media'], tags=[882]),
#  TaggedDocument(words=['corporate', 'media', 'vs', 'national', 'media'], tags=[883]),
#  TaggedDocument(words=['concealing', 'societal', 'function'], tags=[884]),
#  TaggedDocument(words=['tactical', 'disagreements'], tags=[885]),
#  TaggedDocument(words=['the', 'elite', 'consensus'], tags=[886]),
#  TaggedDocument(words=['analysis', 'of', 'the', 'media'], tags=[887]),
#  TaggedDocument(words=['central', 'american', 'peace', 'accords'], tags=[888]),
#  TaggedDocument(words=['military', 'analysis', 'of', 'nicaragua'], tags=[889]),
#  TaggedDocument(words=['involvement', 'in', 'nicaragua'], tags=[890]),
#  TaggedDocument(words=['the', 'proxy', 'army'], tags=[891]),
#  TaggedDocument(words=['civil', 'conflicts', 'in', 'the', 'media'], tags=[892]),
#  TaggedDocument(words=['defense', 'against', 'agression'], tags=[893]),
#  TaggedDocument(words=['impending', 'invasion', 'of', 'nicaragua'], tags=[894]),
#  TaggedDocument(words=['backing', 'of', 'guerrillas', 'in', 'el', 'salvador'], tags=[895]),
#  TaggedDocument(words=['analysis', 'of', 'the', 'central', 'american', 'peace', 'accords'], tags=[896]),
#  TaggedDocument(words=['the', 'press', 'shaping', 'us', 'policy'], tags=[897]),
#  TaggedDocument(words=['is', 'israel', 'democracy'], tags=[898]),
#  TaggedDocument(words=['politics', 'in', 'language'], tags=[899]),
#  TaggedDocument(words=['designed', 'terminology'], tags=[900]),
#  TaggedDocument(words=['terror', 'as', 'symbolic', 'tool'], tags=[901]),
#  TaggedDocument(words=['america', 'propaganda', 'system'], tags=[902]),
#  TaggedDocument(words=['the', 'case', 'of', 'nicaragua'], tags=[903]),
#  TaggedDocument(words=['how', 'to', 'see', 'through', 'propaganda', 'and', 'think', 'critically'], tags=[904]),
#  TaggedDocument(words=['two', 'salient', 'middle', 'east', 'issues'], tags=[905]),
#  TaggedDocument(words=['iran', 'and', 'the', 'international', 'community'], tags=[906]),
#  TaggedDocument(words=['iran', 'and', 'the', 'mafia', 'principle'], tags=[907]),
#  TaggedDocument(words=['anti', 'missile', 'systems', 'as', 'first', 'strike'], tags=[908]),
#  TaggedDocument(words=['all', 'israeli', 'settlements', 'are', 'illegal'], tags=[909]),
#  TaggedDocument(words=['politicide'], tags=[910]),
#  TaggedDocument(words=['the', 'right', 'of', 'self', 'defense', 'by', 'force'], tags=[911]),
#  TaggedDocument(words=['israel', 'and', 'hamas'], tags=[912]),
#  TaggedDocument(words=['the', 'should', 'be', 'the', 'target', 'of', 'activism'], tags=[913]),
#  TaggedDocument(words=['why', 'the', 'must', 'pull', 'out', 'of', 'afghanistan', 'immediately'], tags=[914]),
#  TaggedDocument(words=['how', 'young', 'activists', 'have', 'transformed', 'the'], tags=[915]),
#  TaggedDocument(words=['one', 'state', 'solution', 'or', 'two'], tags=[916]),
#  TaggedDocument(words=['the', 'coup', 'in', 'honduras'], tags=[917]),
#  TaggedDocument(words=['public', 'opinion', 'and', 'israel'], tags=[918]),
#  TaggedDocument(words=['iraq', 'land', 'of', 'wreck', 'ruin'], tags=[919]),
#  TaggedDocument(words=['liberal', 'doves'], tags=[920]),
#  TaggedDocument(words=['nuremberg'], tags=[921]),
#  TaggedDocument(words=['september'], tags=[922]),
#  TaggedDocument(words=['unpeople'], tags=[923]),
#  TaggedDocument(words=['iran'], tags=[924]),
#  TaggedDocument(words=['north', 'korea'], tags=[925]),
#  TaggedDocument(words=['imperial', 'intentions'], tags=[926]),
#  TaggedDocument(words=['iran', 'offer', 'to'], tags=[927]),
#  TaggedDocument(words=['resistance', 'in', 'latin', 'america'], tags=[928]),
#  TaggedDocument(words=['vietnam'], tags=[929]),
#  TaggedDocument(words=['amy', 'goodman', 'introduction'], tags=[930]),
#  TaggedDocument(words=['crisis', 'and', 'hope', 'couple', 'of', 'words', 'about', 'the', 'title'], tags=[931]),
#  TaggedDocument(words=['the', 'food', 'crisis', 'bandgladesh', 'and', 'haiti'], tags=[932]),
#  TaggedDocument(words=['neoliberalism', 'and', 'the', 'inherent', 'deficiency', 'of', 'markets'], tags=[933]),
#  TaggedDocument(words=['state', 'capitalism', 'and', 'the', 'military', 'industrial', 'complex'], tags=[934]),
#  TaggedDocument(words=['wars', 'in', 'iraq', 'afghanistan', 'and', 'pakistan'], tags=[935]),
#  TaggedDocument(words=['american', 'democracy', 'the', 'endgame', 'of', 'the', 'human', 'race'], tags=[936]),
#  TaggedDocument(words=['global', 'warming', 'and', 'the', 'environment'], tags=[937]),
#  TaggedDocument(words=['worker', 'control', 'as', 'american', 'as', 'apple', 'pie'], tags=[938]),
#  TaggedDocument(words=['conclusion', 'short', 'and', 'long', 'term', 'strategies', 'to', 'build', 'resurrect', 'democracy'], tags=[939]),
#  TaggedDocument(words=['history', 'and', 'the', 'second', 'superpower'], tags=[940]),
#  TaggedDocument(words=['controlling', 'the', 'great', 'beast'], tags=[941]),
#  TaggedDocument(words=['rescinding', 'the', 'geneva', 'convention'], tags=[942]),
#  TaggedDocument(words=['demystifying', 'pre', 'emptive', 'war'], tags=[943]),
#  TaggedDocument(words=['the', 'principle', 'of', 'universality'], tags=[944]),
#  TaggedDocument(words=['polling', 'the', 'great', 'beast', 'of', 'public', 'opinion'], tags=[945]),
#  TaggedDocument(words=['the', 'threat', 'of', 'terrorism', 'vs', 'the', 'real', 'priorities'], tags=[946]),
#  TaggedDocument(words=['what', 'the', 'great', 'beast', 'wants', 'and', 'why', 'it', 'is', 'deceived'], tags=[947]),
#  TaggedDocument(words=['what', 'is', 'old', 'europe', 'anyway'], tags=[948]),
#  TaggedDocument(words=['america', 'messianic', 'vision', 'of', 'democracy'], tags=[949]),
#  TaggedDocument(words=['making', 'use', 'of', 'our', 'freedom', 'to', 'fight', 'back'], tags=[950]),
#  TaggedDocument(words=['historical', 'significance', 'of'], tags=[951]),
#  TaggedDocument(words=['latin', 'american', 'victims', 'of', 'tate', 'terror', 'respond', 'to'], tags=[952]),
#  TaggedDocument(words=['turkey', 'and', 'reppression'], tags=[953]),
#  TaggedDocument(words=['the', 'lebanon', 'and', 'israel'], tags=[954]),
#  TaggedDocument(words=['wars', 'on', 'terror', 'old', 'and', 'new', 'and', 'orwellian', 'doublespeak'], tags=[955]),
#  TaggedDocument(words=['israel', 'the', 'and', 'the', 'geneva', 'convention'], tags=[956]),
#  TaggedDocument(words=['good', 'terrorists', 'bad', 'terrorists', 'and', 'monied', 'muslims'], tags=[957]),
#  TaggedDocument(words=['why', 'do', 'they', 'hate', 'us', 'pouring', 'oil', 'on', 'troubled', 'waters', 'then', 'and', 'now'], tags=[958]),
#  TaggedDocument(words=['latin', 'america', 'the', 'and', 'glaobalisation'], tags=[959]),
#  TaggedDocument(words=['same', 'forgien', 'policy', 'same', 'armaments', 'different', 'pretext'], tags=[960]),
#  TaggedDocument(words=['the', 'problems', 'with', 'iraq'], tags=[961]),
#  TaggedDocument(words=['middle', 'east', 'maps', 'plans', 'and', 'peace'], tags=[962]),
#  TaggedDocument(words=['justice', 'and', 'the', 'emerging', 'framework'], tags=[963]),
#  TaggedDocument(words=['venezuela', 'coups', 'and', 'democracy'], tags=[964]),
#  TaggedDocument(words=['peace', 'land', 'and', 'the', 'west', 'bank'], tags=[965]),
#  TaggedDocument(words=['china', 'hopes', 'and', 'fears'], tags=[966]),
#  TaggedDocument(words=['the', 'impediment', 'to', 'peace', 'in', 'the', 'middle', 'east'], tags=[967]),
#  TaggedDocument(words=['doctrinal', 'constraints', 'on', 'middle', 'east', 'peace'], tags=[968]),
#  TaggedDocument(words=['big', 'business', 'and', 'the', 'general', 'population', 'nation', 'divided'], tags=[969]),
#  TaggedDocument(words=['assumptions', 'questions', 'and', 'goals'], tags=[970]),
#  TaggedDocument(words=['afghanistan'], tags=[971]),
#  TaggedDocument(words=['attacks', 'on', 'the', 'us'], tags=[972]),
#  TaggedDocument(words=['attacks', 'by', 'the', 'west'], tags=[973]),
#  TaggedDocument(words=['terrorism', 'and', 'the', 'war', 'on', 'nicaragua'], tags=[974]),
#  TaggedDocument(words=['terrorism', 'works'], tags=[975]),
#  TaggedDocument(words=['freedom', 'fighters', 'and', 'terrorism'], tags=[976]),
#  TaggedDocument(words=['cia', 'and', 'terrorism'], tags=[977]),
#  TaggedDocument(words=['turning', 'against', 'the', 'master'], tags=[978]),
#  TaggedDocument(words=['why', 'do', 'they', 'hate', 'us'], tags=[979]),
#  TaggedDocument(words=['combatting', 'terror'], tags=[980]),
#  TaggedDocument(words=['international', 'relations', 'and', 'the', 'credibility', 'factor'], tags=[981]),
#  TaggedDocument(words=['sensible', 'solutions'], tags=[982]),
#  TaggedDocument(words=['reducing', 'terror', 'enduring', 'freedom'], tags=[983]),
#  TaggedDocument(words=['where', 'the', 'arms', 'are'], tags=[984]),
#  TaggedDocument(words=['military', 'aid', 'to', 'turkey'], tags=[985]),
#  TaggedDocument(words=['terrorism'], tags=[986]),
#  TaggedDocument(words=['colombia'], tags=[987]),
#  TaggedDocument(words=['inequality', 'in', 'latin', 'america'], tags=[988]),
#  TaggedDocument(words=['impact', 'of', 'us', 'intervention'], tags=[989]),
#  TaggedDocument(words=['pacification'], tags=[990]),
#  TaggedDocument(words=['the', 'drug', 'war'], tags=[991]),
#  TaggedDocument(words=['the', 'deeper', 'reasons'], tags=[992]),
#  TaggedDocument(words=['the', 'new', 'imperialism'], tags=[993]),
#  TaggedDocument(words=['globalization'], tags=[994]),
#  TaggedDocument(words=['rational', 'peasants'], tags=[995]),
#  TaggedDocument(words=['what', 'right', 'does', 'the', 'us', 'have', 'to', 'intervene'], tags=[996]),
#  TaggedDocument(words=['the', 'role', 'of', 'us', 'banks'], tags=[997]),
#  TaggedDocument(words=['it', 'well', 'known', 'how', 'to', 'deal', 'with', 'the', 'drug', 'problems'], tags=[998]),
#  TaggedDocument(words=['the', 'real', 'objectives'], tags=[999]),
#  ...]

# %%
model = Doc2Vec(vector_size=100, min_count=1, epochs=50)

# %%
model.build_vocab(music_name_tagged)

# %%
model.dv.vectors
# Out:
# array([[-0.00523082, -0.00597913, -0.00988075, ..., -0.00201204,
#          0.00889517,  0.00235126],
#        [-0.00556037, -0.00318053, -0.00597086, ..., -0.00406312,
#          0.00215229,  0.00532112],
#        [-0.00787459, -0.0092044 ,  0.00841427, ..., -0.00115433,
#          0.00969793, -0.00679331],
#        ...,
#        [-0.00279424,  0.00458743, -0.00997371, ..., -0.00242311,
#          0.00388322,  0.00875279],
#        [ 0.00850275, -0.00704437, -0.00668973, ...,  0.00165882,
#         -0.00107105,  0.00684784],
#        [ 0.00131204, -0.00914756,  0.00945708, ..., -0.0017827 ,
#          0.00580041,  0.00186356]], dtype=float32)

# %%
preprocessed_music_names = pd.DataFrame(model.dv.vectors)
preprocessed_music_names.to_csv(get_root_path() / "data" / "processed" / "vectorized_music_names.csv", index=False)
